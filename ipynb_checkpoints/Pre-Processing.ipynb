# %%
import os
import librosa
import math
import json

# %%
DATASET_PATH = "./Final_Dataset"
JSON_PATH = "data2.json"

SAMPLE_RATE = 22050
DURATION = 0.9230839002267573
SAMPLE_PER_TRACK = SAMPLE_RATE*DURATION

# %%
def save_mfcc(dataset_path,json_path,n_mfcc = 30,n_fft = 2048,hop_length = 512):
    data = {
        "mapping" : [],
        "mfcc" : [],
        "labels" : []
    }
    
    expected_num_mfcc_vectors_per_track = math.ceil(int(SAMPLE_PER_TRACK-100) / hop_length) 
    
    for i, (dirpath,dirnames,filenames) in enumerate(os.walk(dataset_path)):
        #i = 0 gives dirpath directly instead of iterating
        if dirpath is not dataset_path:
            
            #save semantic label
            dirpath_components = dirpath.split("/")
            semantic_label = dirpath_components[-1]
            data["mapping"].append(semantic_label)
            
            print("\n Processing{}".format(semantic_label))
            
            #process files for specific case
            for f in filenames:
                
                #load audio file
                file_path = os.path.join(dirpath,f)
                signal, sr = librosa.load(file_path, sr = SAMPLE_RATE)
                
                #process the entire segment
                mfcc = librosa.feature.mfcc(signal[0:int(SAMPLE_PER_TRACK-100)],
                                            sr = sr,
                                            n_fft = n_fft,
                                            n_mfcc = n_mfcc,
                                            hop_length = hop_length
                                           )
                mfcc = mfcc.T
                
                if(len(mfcc)==expected_num_mfcc_vectors_per_track):
                    data["mfcc"].append(mfcc.tolist())
                    data["labels"].append(i-1)
                    print("{}".format(file_path))
                    
    with open(json_path,"w") as fp:
        json.dump(data,fp,indent=4)

# %%
save_mfcc(DATASET_PATH,JSON_PATH)
# Out:
#  Processingcovid
# ./Final_Dataset/covid/covid-13.wav
# ./Final_Dataset/covid/covid-8.wav
# ./Final_Dataset/covid/covid9.wav
# ./Final_Dataset/covid/covid_4.wav
# ./Final_Dataset/covid/covid2.wav
# ./Final_Dataset/covid/covid_27.wav
# ./Final_Dataset/covid/covid_21.wav
# ./Final_Dataset/covid/covid-29.wav
# ./Final_Dataset/covid/covid3.wav
# ./Final_Dataset/covid/covid-20.wav
# ./Final_Dataset/covid/covid17.wav
# ./Final_Dataset/covid/covid-25.wav
# ./Final_Dataset/covid/covid_29.wav
# ./Final_Dataset/covid/covid7.wav
# ./Final_Dataset/covid/covid_7.wav
# ./Final_Dataset/covid/covid_16.wav
# ./Final_Dataset/covid/covid14.wav
# ./Final_Dataset/covid/covid_20.wav
# ./Final_Dataset/covid/covid15.wav
# ./Final_Dataset/covid/covid-1.wav
# ./Final_Dataset/covid/covid-18.wav
# ./Final_Dataset/covid/covid-2.wav
# ./Final_Dataset/covid/covid16.wav
# ./Final_Dataset/covid/covid5.wav
# ./Final_Dataset/covid/covid_15.wav
# ./Final_Dataset/covid/covid-17.wav
# ./Final_Dataset/covid/covid-16.wav
# ./Final_Dataset/covid/covid-14.wav
# ./Final_Dataset/covid/covid_14.wav
# ./Final_Dataset/covid/covid_1.wav
# ./Final_Dataset/covid/covid_26.wav
# ./Final_Dataset/covid/covid-19.wav
# ./Final_Dataset/covid/covid_28.wav
# ./Final_Dataset/covid/covid-12.wav
# ./Final_Dataset/covid/covid_9.wav
# ./Final_Dataset/covid/covid-21.wav
# ./Final_Dataset/covid/covid-7.wav
# ./Final_Dataset/covid/covid6.wav
# ./Final_Dataset/covid/covid4.wav
# ./Final_Dataset/covid/covid-33.wav
# ./Final_Dataset/covid/covid_32.wav
# ./Final_Dataset/covid/covid_10.wav
# ./Final_Dataset/covid/covid8.wav
# ./Final_Dataset/covid/covid13.wav
# ./Final_Dataset/covid/covid-24.wav
# ./Final_Dataset/covid/covid_13.wav
# ./Final_Dataset/covid/covid10.wav
# ./Final_Dataset/covid/covid_30.wav
# ./Final_Dataset/covid/covid_17.wav
# ./Final_Dataset/covid/covid-32.wav
# ./Final_Dataset/covid/covid_2.wav
# ./Final_Dataset/covid/covid_5.wav
# ./Final_Dataset/covid/covid-5.wav
# ./Final_Dataset/covid/covid-23.wav
# ./Final_Dataset/covid/covid-22.wav
# ./Final_Dataset/covid/covid_3.wav
# ./Final_Dataset/covid/covid_19.wav
# ./Final_Dataset/covid/covid-3.wav
# ./Final_Dataset/covid/covid-6.wav
# ./Final_Dataset/covid/covid-30.wav
# ./Final_Dataset/covid/covid-15.wav
# ./Final_Dataset/covid/covid_18.wav
# ./Final_Dataset/covid/covid11.wav
# ./Final_Dataset/covid/covid_8.wav
# ./Final_Dataset/covid/covid_12.wav
# ./Final_Dataset/covid/covid_11.wav
# ./Final_Dataset/covid/covid_6.wav
# ./Final_Dataset/covid/covid-10.wav
# ./Final_Dataset/covid/covid_24.wav
# ./Final_Dataset/covid/covid-4.wav
# ./Final_Dataset/covid/covid-27.wav
# ./Final_Dataset/covid/covid-28.wav
# ./Final_Dataset/covid/covid-31.wav
# ./Final_Dataset/covid/covid_25.wav
# ./Final_Dataset/covid/covid-9.wav
# ./Final_Dataset/covid/covid12.wav
# ./Final_Dataset/covid/covid_31.wav
# ./Final_Dataset/covid/covid1.wav
# ./Final_Dataset/covid/covid_22.wav
# ./Final_Dataset/covid/covid.wav
# ./Final_Dataset/covid/covid-11.wav
# ./Final_Dataset/covid/covid-26.wav
# ./Final_Dataset/covid/covid_23.wav
#
#  Processingnot-covid
# ./Final_Dataset/not-covid/not_covid_2.wav
# ./Final_Dataset/not-covid/not-covid-3.wav
# ./Final_Dataset/not-covid/not-covid-43.wav
# ./Final_Dataset/not-covid/not-covid-38.wav
# ./Final_Dataset/not-covid/not_covid_50.wav
# ./Final_Dataset/not-covid/not-covid-23.wav
# ./Final_Dataset/not-covid/not_covid_30.wav
# ./Final_Dataset/not-covid/not_covid_46.wav
# ./Final_Dataset/not-covid/not-covid-29.wav
# ./Final_Dataset/not-covid/not_covid_3.wav
# ./Final_Dataset/not-covid/not_covid_44.wav
# ./Final_Dataset/not-covid/not-covid-40.wav
# ./Final_Dataset/not-covid/not_covid_4.wav
# ./Final_Dataset/not-covid/not_covid_1.wav
# ./Final_Dataset/not-covid/not-covid-6.wav
# ./Final_Dataset/not-covid/not_covid_15.wav
# ./Final_Dataset/not-covid/not-covid-37.wav
# ./Final_Dataset/not-covid/not-covid-32.wav
# ./Final_Dataset/not-covid/not_covid_21.wav
# ./Final_Dataset/not-covid/not_covid_43.wav
# ./Final_Dataset/not-covid/not_covid_45.wav
# ./Final_Dataset/not-covid/not_covid_42.wav
# ./Final_Dataset/not-covid/not-covid-27.wav
# ./Final_Dataset/not-covid/not_covid_14.wav
# ./Final_Dataset/not-covid/not-covid-2.wav
# ./Final_Dataset/not-covid/not-covid-41.wav
# ./Final_Dataset/not-covid/not-covid-4.wav
# ./Final_Dataset/not-covid/not_covid_49.wav
# ./Final_Dataset/not-covid/not_covid_32.wav
# ./Final_Dataset/not-covid/not-covid-33.wav
# ./Final_Dataset/not-covid/not-covid-47.wav
# ./Final_Dataset/not-covid/not-covid-26.wav
# ./Final_Dataset/not-covid/not-covid-12.wav
# ./Final_Dataset/not-covid/not_covid_51.wav
# ./Final_Dataset/not-covid/not_covid_38.wav
# ./Final_Dataset/not-covid/not-covid-21.wav
# ./Final_Dataset/not-covid/not-covid-20.wav
# ./Final_Dataset/not-covid/not-covid-48.wav
# ./Final_Dataset/not-covid/not-covid-18.wav
# ./Final_Dataset/not-covid/not_covid_35.wav
# ./Final_Dataset/not-covid/not-covid-35.wav
# ./Final_Dataset/not-covid/not-covid-36.wav
# ./Final_Dataset/not-covid/not_covid_6.wav
# ./Final_Dataset/not-covid/not-covid-45.wav
# ./Final_Dataset/not-covid/not_covid_16.wav
# ./Final_Dataset/not-covid/not-covid-14.wav
# ./Final_Dataset/not-covid/not-covid-39.wav
# ./Final_Dataset/not-covid/not_covid_41.wav
# ./Final_Dataset/not-covid/not-covid-11.wav
# ./Final_Dataset/not-covid/not_covid_47.wav
# ./Final_Dataset/not-covid/not_covid_48.wav
# ./Final_Dataset/not-covid/not_covid_25.wav
# ./Final_Dataset/not-covid/not-covid-50.wav
# ./Final_Dataset/not-covid/not-covid-8.wav
# ./Final_Dataset/not-covid/not_covid_10.wav
# ./Final_Dataset/not-covid/not_covid_40.wav
# ./Final_Dataset/not-covid/not-covid-31.wav
# ./Final_Dataset/not-covid/not_covid_13.wav
# ./Final_Dataset/not-covid/not_covid_24.wav
# ./Final_Dataset/not-covid/not-covid-5.wav
# ./Final_Dataset/not-covid/not_covid_5.wav
# ./Final_Dataset/not-covid/not_covid_18.wav
# ./Final_Dataset/not-covid/not_covid_39.wav
# ./Final_Dataset/not-covid/not_covid_8.wav
# ./Final_Dataset/not-covid/not-covid-30.wav
# ./Final_Dataset/not-covid/not_covid_29.wav
# ./Final_Dataset/not-covid/not_covid_23.wav
# ./Final_Dataset/not-covid/not_covid_12.wav
# ./Final_Dataset/not-covid/not_covid_31.wav
# ./Final_Dataset/not-covid/not_covid_52.wav
# ./Final_Dataset/not-covid/not-covid-7.wav
# ./Final_Dataset/not-covid/not-covid-42.wav
# ./Final_Dataset/not-covid/not_covid_9.wav
# ./Final_Dataset/not-covid/not-covid-19.wav
# ./Final_Dataset/not-covid/not_covid_53.wav
# ./Final_Dataset/not-covid/not_covid_33.wav
# ./Final_Dataset/not-covid/not-covid-49.wav
# ./Final_Dataset/not-covid/not-covid-24.wav
# ./Final_Dataset/not-covid/not_covid_28.wav
# ./Final_Dataset/not-covid/not-covid-16.wav
# ./Final_Dataset/not-covid/not-covid-1.wav
# ./Final_Dataset/not-covid/not_covid_36.wav
# ./Final_Dataset/not-covid/not_covid_26.wav
# ./Final_Dataset/not-covid/not_covid_34.wav
# ./Final_Dataset/not-covid/not_covid_37.wav
# ./Final_Dataset/not-covid/not-covid-34.wav
# ./Final_Dataset/not-covid/not-covid-22.wav
# ./Final_Dataset/not-covid/not-covid-46.wav
# ./Final_Dataset/not-covid/not_covid_20.wav
# ./Final_Dataset/not-covid/not-covid-28.wav
# ./Final_Dataset/not-covid/not_covid_22.wav
# ./Final_Dataset/not-covid/not-covid-25.wav
# ./Final_Dataset/not-covid/not_covid_27.wav
# ./Final_Dataset/not-covid/not_covid_11.wav
# ./Final_Dataset/not-covid/not_covid_19.wav
# ./Final_Dataset/not-covid/not_covid_7.wav
